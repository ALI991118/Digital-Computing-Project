# %% [markdown]
# # angle calculation

# %% [markdown]
# https://colab.research.google.com/drive/1f2C8ycIZXzuMTB5VXzq7sVectPHKiN8r?usp=sharing

# %%
# !pip install mediapipe opencv-python-headless matplotlib

# %%
import mediapipe as mp
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Initialize the MediaPipe pose model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# Define the Angle calculation function
def calculate_angle(a, b, c):
    a = np.array(a)  # the first point
    b = np.array(b)  # The second point (middle point）
    c = np.array(c)  # the third point
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    if angle > 180.0:
        angle = 360 - angle
    return angle

# Image processing and attitude detection functions
def process_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    return image, results

# upload images
uploaded = files.upload()
image_files = uploaded.keys()

# Initializes the Angle data dictionary
angles_data = {
    'angle1': [], 'angle2': [], 'angle3': [], 'angle4': [],
    'angle5': [], 'angle6': [], 'angle7': [], 'angle8': []
}

# Process each image
for image_file in image_files:
    image, results = process_image(image_file)
    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark

        # Get key point coordinates
        def get_coords(pose_landmark):
            return [landmarks[pose_landmark.value].x * image.shape[1], landmarks[pose_landmark.value].y * image.shape[0]]

        # Calculating joint Angle
        angles_data['angle1'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_WRIST)))
        angles_data['angle2'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_WRIST)))
        angles_data['angle3'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_HIP)))
        angles_data['angle4'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_HIP)))
        angles_data['angle5'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_KNEE)))
        angles_data['angle6'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_KNEE)))
        angles_data['angle7'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_KNEE),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_ANKLE)))
        angles_data['angle8'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_KNEE),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_ANKLE)))

# Calculate the mean and standard deviation for each Angle
for angle_name, angles in angles_data.items():
    if angles:
        print(f"{angle_name}: Mean = {np.mean(angles):.2f}, Std Dev = {np.std(angles):.2f}")
# Out:
#      <input type="file" id="files-3074bd59-59b2-46a4-8cd8-47df94c39ff9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3074bd59-59b2-46a4-8cd8-47df94c39ff9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import mediapipe as mp
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files


mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)


def calculate_angle(a, b, c):
    a = np.array(a)  
    b = np.array(b) 
    c = np.array(c) 
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    if angle > 180.0:
        angle = 360 - angle
    return angle


def process_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image)
    return image, results


uploaded = files.upload()
image_files = uploaded.keys()


angles_data = {
    'angle1': [], 'angle2': [], 'angle3': [], 'angle4': [],
    'angle5': [], 'angle6': [], 'angle7': [], 'angle8': []
}


for image_file in image_files:
    image, results = process_image(image_file)
    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark


        def get_coords(pose_landmark):
            return [landmarks[pose_landmark.value].x * image.shape[1], landmarks[pose_landmark.value].y * image.shape[0]]

     
        angles_data['angle1'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_WRIST)))
        angles_data['angle2'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_WRIST)))
        angles_data['angle3'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_HIP)))
        angles_data['angle4'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_ELBOW),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_HIP)))
        angles_data['angle5'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_KNEE)))
        angles_data['angle6'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_SHOULDER),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_KNEE)))
        angles_data['angle7'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.RIGHT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_KNEE),
                                                     get_coords(mp_pose.PoseLandmark.RIGHT_ANKLE)))
        angles_data['angle8'].append(calculate_angle(get_coords(mp_pose.PoseLandmark.LEFT_HIP),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_KNEE),
                                                     get_coords(mp_pose.PoseLandmark.LEFT_ANKLE)))


for angle_name, angles in angles_data.items():
    if angles:
        print(f"{angle_name}: Mean = {np.mean(angles):.2f}, Std Dev = {np.std(angles):.2f}")
# Out:
#      <input type="file" id="files-5f827077-e6b4-454d-b19d-b408eb13c707" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f827077-e6b4-454d-b19d-b408eb13c707">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
